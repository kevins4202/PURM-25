# %%
import os
import shutil
from pathlib import Path
from collections import defaultdict
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/kevinsong/Documents/programming/purm/PURM-25/data/chop'

# %%
def organize_files():
    # Define source and destination paths
    base_path = Path("original")
    annotated_source = base_path / "annotated_files"
    original_source = base_path / "original_files"
    
    # Define destination paths
    combined_path = Path("combined")
    annotated_dest = combined_path / "annotations"
    notes_dest = combined_path / "notes"
    
    # Create destination directories if they don't exist
    annotated_dest.mkdir(parents=True, exist_ok=True)
    notes_dest.mkdir(parents=True, exist_ok=True)
    
    # Counter for moved files
    ann_files_moved = 0
    txt_files_moved = 0
    
    print("Starting file organization...")
    files_and_counts = {}
    
    # Move all .ann files from annotated_files subdirectories
    if annotated_source.exists():
        for root, dirs, files in os.walk(annotated_source):
            for file in files:
                if file.endswith('.ann'):
                    source_path = Path(root) / file
                    dest_path = annotated_dest / file
                    
                    # Handle duplicate filenames by adding a suffix
                    counter = 1
                    original_dest_path = dest_path
                    while dest_path.exists():
                        name, ext = original_dest_path.stem, original_dest_path.suffix
                        dest_path = annotated_dest / f"{name}_{counter}{ext}"
                        counter += 1
                    
                    try:
                        shutil.copy2(source_path, dest_path)
                        print(f"Moved .ann file: {source_path} -> {dest_path}")
                        ann_files_moved += 1
                    except Exception as e:
                        print(f"Error moving {source_path}: {e}")
    
    # Move all .txt files from original_files subdirectories
    if original_source.exists():
        for root, dirs, files in os.walk(original_source):
            for file in files:
                if file.endswith('.txt'):
                    source_path = Path(root) / file
                    dest_path = notes_dest / file
                    
                    # Handle duplicate filenames by adding a suffix
                    if dest_path.exists():
                        assert file in files_and_counts

                        files_and_counts[file] += 1
                        continue
                    
                    try:
                        files_and_counts[file] = 1
                        shutil.copy2(source_path, dest_path)
                        print(f"Moved .txt file: {source_path} -> {dest_path}")
                        txt_files_moved += 1
                    except Exception as e:
                        print(f"Error moving {source_path}: {e}")
    
    print(f"\nFile organization complete!")
    print(f"Total .ann files moved: {ann_files_moved}")
    print(f"Total .txt files moved: {txt_files_moved}")

    print(files_and_counts)
    csv_filename = "file_copies.csv"
    with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['filename', 'copies']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        writer.writeheader()
        for k, v in files_and_counts.items():
            writer.writerow({
                'filename': k,
                'copies': v
            })

# %%
organize_files()
# Out:
# Starting file organization...
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/792948743.ann -> combined/annotations/792948743.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/804045612.ann -> combined/annotations/804045612.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/798507904.ann -> combined/annotations/798507904.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/779183024.ann -> combined/annotations/779183024.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/785000449.ann -> combined/annotations/785000449.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/793084875.ann -> combined/annotations/793084875.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/776431140.ann -> combined/annotations/776431140.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/759511715.ann -> combined/annotations/759511715.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/771650368.ann -> combined/annotations/771650368.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/803876336.ann -> combined/annotations/803876336.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/742651922.ann -> combined/annotations/742651922.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/746965405.ann -> combined/annotations/746965405.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/798713223.ann -> combined/annotations/798713223.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/748444760.ann -> combined/annotations/748444760.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/758037306.ann -> combined/annotations/758037306.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/781773363.ann -> combined/annotations/781773363.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long/801051895.ann -> combined/annotations/801051895.ann
# Moved .ann file: original/annotated_files/stage1_part3/Angela_Long
3.ann
# Moved .ann file: original/annotated_files/stage1_part3/Emma_Olshin/768815667.ann -> combined/annotations/768815667_3.ann
# Moved .ann file: original/annotated_files/stage1_part3/Emma_Olshin/734332849.ann -> combined/annotations/734332849_3.ann
# Moved .ann file: original/annotated_files/stage0_training/Z3332554_substance_abuse.ann -> combined/annotations/Z3332554_substance_abuse.ann
# Moved .ann file: original/annotated_files/stage0_training/Z3436303_housing_instability.ann -> combined/annotations/Z3436303_housing_instability.ann
# Moved .ann file: original/annotated_files/stage0_training/Z3158695_childcare.ann -> combined/annotations/Z3158695_childcare.ann
# Moved .ann file: original/annotated_files/stage0_training/Z897449_transportation.ann -> combined/annotations/Z897449_transportation.ann
# Moved .ann file: original/annotated_files/stage0_training/Z3270571_parent_employment.ann -> combined/annotations/Z3270571_parent_employment.ann
# Moved .ann file: original/annotated_files/stage0_training/Z3407997_food_insecurity.ann -> combined/annotations/Z3407997_food_insecurity.ann
# Moved .ann file: original/annotated_files/stage0_training/Z1725330_financial_strain.ann -> combined/annotations/Z1725330_financial_strain.ann
# Moved .ann file: original/annotated_files/stage0_training/Z3397001_safety.ann -> combined/annotations/Z3397001_safety.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/765925964.ann -> combined/annotations/765925964.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/810089169.ann -> combined/annotations/810089169.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/797805510.ann -> combined/annotations/797805510.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/764679905.ann -> combined/annotations/764679905.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/744173368.ann -> combined/annotations/744173368.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/804257333.ann -> combined/annotations/804257333.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/795228404.ann -> combined/annotations/795228404.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/750399483.ann -> combined/annotations/750399483.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/777218429.ann -> combined/annotations/777218429.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/744375909.ann -> combined/annotations/744375909.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/799345370.ann -> combined/annotations/799345370.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/751097166.ann -> combined/annotations/751097166.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/767847492.ann -> combined/annotations/767847492.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/734766290.ann -> combined/annotations/734766290.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/735442263.ann -> combined/annotations/735442263.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/759861099.ann -> combined/annotations/759861099.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/796718222.ann -> combined/annotations/796718222.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/802376323.ann -> combined/annotations/802376323.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/806340991.ann -> combined/annotations/806340991.ann
# Moved .ann file: original/annotated_files/stage1_part2/Angela_Long/806902810.ann -> combined/annotations/806902810.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/765925964.ann -> combined/annotations/765925964_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/810089169.ann -> combined/annotations/810089169_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/797805510.ann -> combined/annotations/797805510_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/764679905.ann -> combined/annotations/764679905_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/744173368.ann -> combined/annotations/744173368_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/804257333.ann -> combined/annotations/804257333_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/795228404.ann -> combined/annotations/795228404_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/750399483.ann -> combined/annotations/750399483_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/777218429.ann -> combined/annotations/777218429_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/744375909.ann -> combined/annotations/744375909_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/799345370.ann -> combined/annotations/799345370_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/751097166.ann -> combined/annotations/751097166_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/767847492.ann -> combined/annotations/767847492_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/734766290.ann -> combined/annotations/734766290_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/735442263.ann -> combined/annotations/735442263_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/759861099.ann -> combined/annotations/759861099_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/796718222.ann -> combined/annotations/796718222_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/802376323.ann -> combined/annotations/802376323_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/806340991.ann -> combined/annotations/806340991_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Elsa_Dahan/806902810.ann -> combined/annotations/806902810_1.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/765925964.ann -> combined/annotations/765925964_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/810089169.ann -> combined/annotations/810089169_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/797805510.ann -> combined/annotations/797805510_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/764679905.ann -> combined/annotations/764679905_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/744173368.ann -> combined/annotations/744173368_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/804257333.ann -> combined/annotations/804257333_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/795228404.ann -> combined/annotations/795228404_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/750399483.ann -> combined/annotations/750399483_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/777218429.ann -> combined/annotations/777218429_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/744375909.ann -> combined/annotations/744375909_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/799345370.ann -> combined/annotations/799345370_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber/751097166.ann -> combined/annotations/751097166_2.ann
# Moved .ann file: original/annotated_files/stage1_part2/Liz_Lieber
txt
# Moved .txt file: original/original_files/Extra_Notes_March2025/Emma_Olshin/778000723.txt -> combined/notes/778000723.txt
# Moved .txt file: original/original_files/Extra_Notes_March2025/Emma_Olshin/803434883.txt -> combined/notes/803434883.txt
# Moved .txt file: original/original_files/stage0_training_plus2/safety_808305960_Z3506755.txt -> combined/notes/safety_808305960_Z3506755.txt
# Moved .txt file: original/original_files/stage0_training_plus2/housing_instability_781822618_Z3241498.txt -> combined/notes/housing_instability_781822618_Z3241498.txt
# Moved .txt file: original/original_files/stage0_training_plus2/parent_employment_807626253_Z3478630.txt -> combined/notes/parent_employment_807626253_Z3478630.txt
# Moved .txt file: original/original_files/stage0_training_plus2/childcare_805471532_Z1725330.txt -> combined/notes/childcare_805471532_Z1725330.txt
# Moved .txt file: original/original_files/stage0_training_plus2/substance_abuse_734895220_Z1571626.txt -> combined/notes/substance_abuse_734895220_Z1571626.txt
# Moved .txt file: original/original_files/stage0_training_plus2/financial_strain_738809058_Z998494.txt -> combined/notes/financial_strain_738809058_Z998494.txt
# Moved .txt file: original/original_files/stage0_training_plus2/transportation_805386989_Z3488131.txt -> combined/notes/transportation_805386989_Z3488131.txt
# Moved .txt file: original/original_files/stage0_training_plus2/safety_805833529_Z3495747.txt -> combined/notes/safety_805833529_Z3495747.txt
# Moved .txt file: original/original_files/stage0_training_plus2/food_insecurity_771346971_Z3434149.txt -> combined/notes/food_insecurity_771346971_Z3434149.txt
# Moved .txt file: original/original_files/stage0_training_plus2/parent_employment_809125657_Z3477046.txt -> combined/notes/parent_employment_809125657_Z3477046.txt
# Moved .txt file: original/original_files/stage0_training_plus2/financial_strain_760903485_Z2988009.txt -> combined/notes/financial_strain_760903485_Z2988009.txt
# Moved .txt file: original/original_files/stage0_training_plus2/housing_instability_765771763_Z3292823.txt -> combined/notes/housing_instability_765771763_Z3292823.txt
# Moved .txt file: original/original_files/stage0_training_plus2/substance_abuse_756526269_Z3311760.txt -> combined/notes/substance_abuse_756526269_Z3311760.txt
# Moved .txt file: original/original_files/stage0_training_plus2/transportation_800152521_Z3478945.txt -> combined/notes/transportation_800152521_Z3478945.txt
# Moved .txt file: original/original_files/stage0_training_plus2/food_insecurity_758433908_Z3417391.txt -> combined/notes/food_insecurity_758433908_Z3417391.txt
# Moved .txt file: original/original_files/stage0_training_plus2/childcare_783775239_Z3435731.txt -> combined/notes/childcare_783775239_Z3435731.txt
#
# File organization complete!
# Total .ann files moved: 3828
# Total .txt files moved: 3456
# {'798507904.txt': 4, '804045612.txt': 4, '792948743.txt': 4, '793084875.txt': 5, '759511715.txt': 4, '776431140.txt': 5, '779183024.txt': 5, '785000449.txt': 5, '742651922.txt': 5, '746965405.txt': 5, '798713223.txt': 4, '771650368.txt': 4, '803876336.txt': 5, '768815667.txt': 4, '734332849.txt': 5, '801051895.txt': 5, '781773363.txt': 5, '758037306.txt': 4, '748444760.txt': 5, '764662087.txt': 5, 'Z3436303_housing_instability.txt': 1, 'Z3158695_childcare.txt': 1, 'Z3332554_substance_abuse.txt': 1, 'Z3270571_parent_employment.txt': 1, 'Z897449_transportation.txt': 1, 'Z3407997_food_insecurity.txt': 1, 'Z3397001_safety.txt': 1, 'Z1725330_financial_strain.txt': 1, '795228404.txt': 4, '804257333.txt': 4, '744173368.txt': 4, '764679905.txt': 4, '777218429.txt
009739.txt': 1, '791301358.txt': 1, '767561524.txt': 1, '768462694.txt': 1, '806326776.txt': 1, '748529219.txt': 1, '746725123.txt': 1, '765526003.txt': 1, '775436693.txt': 1, '773690438.txt': 1, '788206958.txt': 1, '763149783.txt': 1, '792854569.txt': 1, '752936156.txt': 1, '750462085.txt': 1, '749100423.txt': 1, '788845123.txt': 1, '770052462.txt': 1, '802618563.txt': 1, '790319950.txt': 1, '789526132.txt': 1, '798428892.txt': 1, '799164549.txt': 1, '807901785.txt': 1, '79972761 ...

# %%
LABELS = [
        "PatientCaregiver_Unemployment",
        "Homelessness",
        "GeneralHousingInstability",
        "NeedTemporaryLodging",
        "HouseInstability_Other",
        "LackofFundsforFood",
        "FoodInsecurity_Other",
        "Poverty",
        "LackofInsurance",
        "UnabletoPay",
        "FinancialStrain_Other",
        "DistancefromHospital",
        "LackofTransportation",
        "Transportation_Other",
        "ChildcareBarrierfromHospitalization",
        "ChildcareBarrierfromNonHospitalization",
        "NeedofChildcare",
        "Childcare_Other",
        "DrugUse",
        "Alcoholism",
        "SubstanceAbuse_Other",
        "ChildAbuse",
        "HomeSafety",
        "HomeAccessibility",
        "IntimatePartnerViolence",
        "HomeEnvironment_Other",
        "CommunitySafety",
        "CommunityAccessibility",
        "CommunityViolence",
        "CommunityEnvironment_Other",
        "NonPermanentPlacement",
        "PermanentPlacementPending",
        "Permanency_Other",
    ]

# %%
len(LABELS)
# Out:
# 33

# %%
cat_to_labels = {
    "PatientCaregiver_Employment": [
        "PatientCaregiver_Unemployment"
    ],
    "HousingInstability": [
        "Homelessness",
        "GeneralHousingInstability",
        "NeedTemporaryLodging",
        "HouseInstability_Other"
    ],
    "FoodInsecurity": [
        "LackofFundsforFood",
        "FoodInsecurity_Other"
    ],
    "FinancialStrain": [
        "Poverty",
        "LackofInsurance",
        "UnabletoPay",
        "FinancialStrain_Other"
    ],
    "Transportation": [
        "DistancefromHospital",
        "LackofTransportation",
        "Transportation_Other"
    ],
    "Childcare": [
        "ChildcareBarrierfromHospitalization",
        "ChildcareBarrierfromNonHospitalization",
        "NeedofChildcare",
        "Childcare_Other"
    ],
    "SubstanceAbuse": [
        "DrugUse",
        "Alcoholism",
        "SubstanceAbuse_Other"
    ],
    "Safety": [
        # Home environment
            "ChildAbuse",
            "HomeSafety",
            "HomeAccessibility",
            "IntimatePartnerViolence",
            "HomeEnvironment_Other",
        # Community environment
            "CommunitySafety",
            "CommunityAccessibility",
            "CommunityViolence",
            "CommunityEnvironment_Other"
        ],
    "Permanency": [
        "NonPermanentPlacement",
        "PermanentPlacementPending",
        "Permanency_Other"
    ]
}

# %%
label_to_cat = {v: k for k, vals in cat_to_labels.items() for v in vals }

# %%
label_to_cat
# Out:
# {'PatientCaregiver_Unemployment': 'PatientCaregiver_Employment',
#  'Homelessness': 'HousingInstability',
#  'GeneralHousingInstability': 'HousingInstability',
#  'NeedTemporaryLodging': 'HousingInstability',
#  'HouseInstability_Other': 'HousingInstability',
#  'LackofFundsforFood': 'FoodInsecurity',
#  'FoodInsecurity_Other': 'FoodInsecurity',
#  'Poverty': 'FinancialStrain',
#  'LackofInsurance': 'FinancialStrain',
#  'UnabletoPay': 'FinancialStrain',
#  'FinancialStrain_Other': 'FinancialStrain',
#  'DistancefromHospital': 'Transportation',
#  'LackofTransportation': 'Transportation',
#  'Transportation_Other': 'Transportation',
#  'ChildcareBarrierfromHospitalization': 'Childcare',
#  'ChildcareBarrierfromNonHospitalization': 'Childcare',
#  'NeedofChildcare': 'Childcare',
#  'Childcare_Other': 'Childcare',
#  'DrugUse': 'SubstanceAbuse',
#  'Alcoholism': 'SubstanceAbuse',
#  'SubstanceAbuse_Other': 'SubstanceAbuse',
#  'ChildAbuse': 'Safety',
#  'HomeSafety': 'Safety',
#  'HomeAccessibility': 'Safety',
#  'IntimatePartnerViolence': 'Safety',
#  'HomeEnvironment_Other': 'Safety',
#  'CommunitySafety': 'Safety',
#  'CommunityAccessibility': 'Safety',
#  'CommunityViolence': 'Safety',
#  'CommunityEnvironment_Other': 'Safety',
#  'NonPermanentPlacement': 'Permanency',
#  'PermanentPlacementPending': 'Permanency',
#  'Permanency_Other': 'Permanency'}

# %%
len(label_to_cat.keys())
# Out:
# 33

# %%
cats = list(cat_to_labels.keys())

# %%
cats
# Out:
# ['PatientCaregiver_Employment',
#  'HousingInstability',
#  'FoodInsecurity',
#  'FinancialStrain',
#  'Transportation',
#  'Childcare',
#  'SubstanceAbuse',
#  'Safety',
#  'Permanency']

# %%
cats_to_i = {c: i for i, c in enumerate(cats)}

# %%
cats_to_i
# Out:
# {'PatientCaregiver_Employment': 0,
#  'HousingInstability': 1,
#  'FoodInsecurity': 2,
#  'FinancialStrain': 3,
#  'Transportation': 4,
#  'Childcare': 5,
#  'SubstanceAbuse': 6,
#  'Safety': 7,
#  'Permanency': 8}

# %%
with open("combined/annotations/732377980.ann", "r") as f:
    f.readline()
    content = f.readline()
    print(content)
    print(content.split("\t")[1].strip().split(' '))
# Out:
# A1	Negated T1
#
# ['Negated', 'T1']

# %%
import csv

def search_annotations():
    # Path to annotations directory
    annotations_dir = Path("combined/annotations")
    
    # Results storage
    processed_files = []
    blank_files = 0
    non_blank_files = 0
    print("Searching for annotation labels in .ann files...")
    
    # Process each .ann file
    for ann_file in annotations_dir.glob("*.ann"):
        with open(ann_file, 'r') as f:
            # read in the line with the label and the next one (which might have annotations)
            label_index_to_label = {}
            negated_indicies = []
            
            negated_labels = []
            found_labels = []
            
            line = f.readline() # example: T1	FinancialStrain_Other 482 540	SW provided mother with financial assistance applications.
                
            while line:
                line = line.strip().split('\t')
                index = line[0]
                
                if index[0] == 'T':
                    current_label = line[1].split(' ')[0]
                    if current_label != "NoSocialNeedsFoundLabel":
                        assert current_label in LABELS, ann_file.name + " " + current_label
                    
                        # add the line to the dict
                        label_index_to_label[index] = current_label
                # check for negated annotation
                elif index[0] == 'A':
                    annotation = line[1].split(' ')
                    assert annotation[0] in ["Negated", "Speculation", "Resolved", "HistoryOf", "SubjectIsNotPatient", "Unsure", "ResolutioninProgress", "NoSocialNeedsFound"]
                    if annotation[0] in ["Negated"]:
                        negated_index = annotation[1]
                        assert negated_index[0] == 'T'
                        negated_indicies.append(negated_index)

                line = f.readline()

            for negated_i in negated_indicies:
                assert negated_i in label_index_to_label
                negated_labels.append(label_index_to_label[negated_i])
                del label_index_to_label[negated_i]

            negated_labels = list(set(negated_labels))
            found_labels = list(set(label_index_to_label.values()))

            negated_cats = list(set([label_to_cat[l] for l in negated_labels]))
            found_cats = list(set([label_to_cat[l] for l in found_labels]))

            cats_map = {}
            
            for cat in cats:
                if cat in found_cats:
                    cats_map[cats_to_i[cat]] = '+'
                elif cat in negated_cats:
                    cats_map[cats_to_i[cat]] = '-'
            
            # Store results
            processed_files.append({
                'file': ann_file.name,
                'labels_positive': found_labels,
                'labels_negated': negated_labels,
                'cats': ';'.join([str(k)+v for k, v in cats_map.items()])
            })

            if processed_files[-1]['cats'] == '':
                blank_files += 1
            else:
                non_blank_files += 1 
                    
    # Create CSV file with results
    csv_filename = "labels_initial.csv"
    with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['file', 'cats']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        writer.writeheader()
        for result in processed_files:
            writer.writerow({
                'file': result['file'],
                'cats': result['cats']
            })
    
    # Print summary
    print(f"\n=== SUMMARY ===")
    print(f"Total .ann files processed: {len(processed_files)}")
    print(f"Blank files: {blank_files}")
    print(f"Non blank files: {non_blank_files}")
    print(f"Results saved to: {csv_filename}")

    """
    # Print files without labels
    print(f"\n=== FILES WITH NO LABELS FOUND ===")
    for filename in sorted(files_without_labels):
        print(f"  - {filename}")

    print(f"\n=== BLANK FILES ===")
    for filename in sorted(files_blank):
        print(f"  - {filename}")
    """
    
    # Print detailed breakdown of labels found
    print(f"\n=== LABEL BREAKDOWN ===")
    label_neg = {}
    label_pos = {}
    for result in processed_files:
        for label in result['labels_positive']:
            label_neg[label] = label_neg.get(label, 0) + 1
        for label in result['labels_negated']:
            label_pos[label] = label_pos.get(label, 0) + 1

    for label in LABELS:
        print(f"\n{label}")
        print(f"+: {label_neg.get(label, 0)}, -: {label_pos.get(label, 0)}")

# %%
search_annotations()
# Out:
# Searching for annotation labels in .ann files...
#
# === SUMMARY ===
# Total .ann files processed: 3828
# Blank files: 1771
# Non blank files: 2057
# Results saved to: labels_initial.csv
#
# === LABEL BREAKDOWN ===
#
# PatientCaregiver_Unemployment
# +: 118, -: 371
#
# Homelessness
# +: 13, -: 0
#
# GeneralHousingInstability
# +: 35, -: 10
#
# NeedTemporaryLodging
# +: 313, -: 15
#
# HouseInstability_Other
# +: 22, -: 1
#
# LackofFundsforFood
# +: 50, -: 52
#
# FoodInsecurity_Other
# +: 49, -: 2
#
# Poverty
# +: 0, -: 0
#
# LackofInsurance
# +: 192, -: 221
#
# UnabletoPay
# +: 21, -: 3
#
# FinancialStrain_Other
# +: 1071, -: 29
#
# DistancefromHospital
# +: 214, -: 39
#
# LackofTransportation
# +: 215, -: 112
#
# Transportation_Other
# +: 25, -: 0
#
# ChildcareBarrierfromHospitalization
# +: 78, -: 29
#
# ChildcareBarrierfromNonHospitalization
# +: 49, -: 5
#
# NeedofChildcare
# +: 16, -: 18
#
# Childcare_Other
# +: 5, -: 0
#
# DrugUse
# +: 47, -: 4
#
# Alcoholism
# +: 1, -: 2
#
# SubstanceAbuse_Other
# +: 30, -: 5
#
# ChildAbuse
# +: 21, -: 10
#
# HomeSafety
# +: 75, -: 14
#
# HomeAccessibility
# +: 22, -: 12
#
# IntimatePartnerViolence
# +: 13, -: 3
#
# HomeEnvironment_Other
# +: 291, -: 1
#
# CommunitySafety
# +: 11, -: 6
#
# CommunityAccessibility
# +: 2, -: 0
#
# CommunityViolence
# +: 4, -: 0
#
# CommunityEnvironment_Other
# +: 4, -: 0
#
# NonPermanentPlacement
# +: 77, -: 346
#
# PermanentPlacementPending
# +: 131, -: 0
#
# Permanency_Other
# +: 5, -: 2

# %%
data = pd.read_csv("labels_initial.csv")

# %%
data.head()
# Out:
#               file   cats
# 0    759200223.ann     3+
# 1    808961801.ann    NaN
# 2  740299111_3.ann    NaN
# 3  796974687_1.ann  6-;7-
# 4  782298339_3.ann    NaN

# %%
data_sorted = data.sort_values('file')

# %%
data_sorted[50:100]
# Out:
#                  file            cats
# 1491    734763697.ann              7+
# 1928    734766290.ann           6+;7+
# 2188  734766290_1.ann           6+;7+
# 1968  734766290_2.ann           6+;7+
# 2097  734766290_3.ann           6+;7+
# 3379    735101136.ann              8+
# 1183    735115660.ann     3-;6+;7+;8-
# 2516    735151429.ann             NaN
# 1121    735247559.ann             NaN
# 3817    735259867.ann           1+;3+
# 1117    735380774.ann             NaN
# 2094    735442263.ann             NaN
# 1913  735442263_1.ann             NaN
# 1668  735442263_2.ann             NaN
# 1473  735442263_3.ann             NaN
# 3008    735631685.ann             NaN
# 2550    735858071.ann             NaN
# 1368    735867514.ann        0-;3-;8-
# 2783  735867514_1.ann             NaN
# 34      735884003.ann             NaN
# 1503    735946482.ann              3+
# 1728    735947760.ann  2-;4+;6+;7+;8-
# 942     735948431.ann           6+;7+
# 519     736043112.ann             NaN
# 2639    736116422.ann             NaN
# 1082    736156397.ann             NaN
# 3556    736158512.ann              3+
# 112     736234912.ann             NaN
# 1141    736280032.ann             NaN
# 3731  736280032_1.ann             NaN
# 3497  736280032_2.ann             NaN
# 3434  736280032_3.ann             NaN
# 3025  736280032_4.ann             NaN
# 992     736533459.ann             NaN
# 139     736555812.ann        5+;6+;8-
# 1202    736583416.ann              3+
# 670     736599167.ann             NaN
# 2160    736600753.ann             NaN
# 3040    736611398.ann             NaN
# 3427    736629774.ann             NaN
# 55      736631849.ann     0-;3+;4-;8-
# 417     736879351.ann             NaN
# 2228    736891241.ann     0-;3+;5+;8-
# 911   736891241_1.ann             NaN
# 2030    736947836.ann             NaN
# 1874    737137281.ann             NaN
# 283     737137554.ann             NaN
# 598     737165161.ann             NaN
# 3289    737173295.ann             NaN
# 462     737173854.ann             NaN
